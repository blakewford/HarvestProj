# %%
import numpy as np
import pandas as pd

# %%
#read in data from Land Database Data Only 2016
#Downloaded from https://data.austintexas.gov/Locations-and-Maps/Land-Database-Data-Only-2016/4nsn-uea6 11/14/2109
#Change next line to local directory with the file - it is not in the git repo
df1 = pd.read_csv("~/datasets/Land_Database/Land_Database_Data_Only_2016.csv")#, header = None)  #TODO - handle file path better
# Out:
# /home/leebhinkle/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,14,18,19,21,22,23,24,25,26,38,39,40,41,42,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.describe()
# Out:
#              PID_10       PROP_ID     PREVIOUSLU     PREVIOUSGE  \
# count  2.482400e+05  2.654220e+05  265422.000000  265422.000000
# mean   2.719576e+08  3.464178e+05     204.234408     181.891584
# std    1.074582e+08  5.050209e+05     244.725821     217.087780
# min    2.320400e+04  0.000000e+00       0.000000       0.000000
# 25%    2.035126e+08  1.985842e+05     100.000000     100.000000
# 50%    2.452805e+08  2.991415e+05     100.000000     100.000000
# 75%    4.050803e+08  4.845978e+05     100.000000     100.000000
# max    1.068440e+09  1.355003e+08     940.000000     940.000000
#
#             LAND_USE   GEN_LAND_USE  SOURCE          UNITS       GISLINK  \
# count  265422.000000  265422.000000     0.0  265422.000000  2.478400e+05
# mean      186.399432     182.503866     NaN       1.739283  2.720190e+08
# std       221.519299     218.553841     NaN      13.623377  1.074212e+08
# min         0.000000       0.000000     NaN       0.000000  4.000400e+04
# ...

# %%
df1.describe(include='all')
# Out:
#               PID_10       PROP_ID    CONDOID     PREVIOUSLU     PREVIOUSGE  \
# count   2.482400e+05  2.654220e+05       1663  265422.000000  265422.000000
# unique           NaN           NaN       1662            NaN            NaN
# top              NaN           NaN  1501-1503            NaN            NaN
# freq             NaN           NaN          2            NaN            NaN
# mean    2.719576e+08  3.464178e+05        NaN     204.234408     181.891584
# std     1.074582e+08  5.050209e+05        NaN     244.725821     217.087780
# min     2.320400e+04  0.000000e+00        NaN       0.000000       0.000000
# 25%     2.035126e+08  1.985842e+05        NaN     100.000000     100.000000
# 50%     2.452805e+08  2.991415e+05        NaN     100.000000     100.000000
# 75%     4.050803e+08  4.845978e+05        NaN     100.000000     100.000000
# max     1.068440e+09  1.355003e+08        NaN     940.000000     940.000000
#
# ...

# %%
df1
# Out:
#              PID_10  PROP_ID CONDOID  PREVIOUSLU  PREVIOUSGE  LAND_USE  \
# 0       100030105.0   100008     NaN         300         300       300
# 1       100030109.0   100012     NaN         330         330       330
# 2       100030110.0   100013     NaN         300         300       300
# 3       100030111.0   100014     NaN         300         300       300
# 4       100030112.0   100015     NaN         300         300       300
# 5       100030115.0   100018     NaN         300         300       300
# 6       100030116.0   100019     NaN         300         300       300
# 7       100030117.0   365458     NaN         300         300       300
# 8       100030201.0   100020     NaN         520         500       520
# 9       100030203.0   100022     NaN         400         400       400
# 10      100030204.0   100023     NaN         900         900       900
# 11      100030205.0   100024     NaN         300         300       300
# ...

# %%
#dfCondo = df1[df1['CONDOID'].isnull()]
dfCondo = df1[df1['PID_10'].isnull()]
#dfCondo = df1[df1['CONDOID']==1200]
dfCondo
# Out:
#         PID_10  PROP_ID CONDOID  PREVIOUSLU  PREVIOUSGE  LAND_USE  \
# 220691     NaN        0     NaN         160         160       160
# 220705     NaN        0     NaN         160         160       160
# 220719     NaN        0     NaN         160         160       160
# 220788     NaN        0     NaN         910         900       910
# 220802     NaN        0     NaN         160         160       160
# 220816     NaN    41867     NaN         900         900       900
# 220869     NaN        0     NaN         160         160       160
# 220909     NaN   113108     NaN         900         900       900
# 220949     NaN        0     NaN         160         160       160
# 220963     NaN        0     NaN         160         160       160
# 220991     NaN        0     NaN         900         900       900
# 221005     NaN        0     NaN         160         160       160
# 221033     NaN        0     NaN         100         100       100
# ...

# %%
list(df1.columns)
# Out:
# ['PID_10',
#  'PROP_ID',
#  'CONDOID',
#  'PREVIOUSLU',
#  'PREVIOUSGE',
#  'LAND_USE',
#  'GEN_LAND_USE',
#  'LU_DESC',
#  'GEN_LU_DESC',
#  'SOURCE',
#  'NOTES',
#  'UNITS',
#  'GISLINK',
#  'Cnt_GISLIN',
#  'PROP_TYPE',
#  'PROPVAL_YR',
#  'SUP_NUM',
#  'PY_OWNER_ID',
#  'OWNER',
#  'SITUS',
#  'LEGAL_DESC',
#  'LEGAL_DESC2',
#  'ABS_SUBDV_CD',
#  'HOOD_CD',
#  'BLOCK',
#  'TRACT_OR_LOT',
#  'DBA',
#  'DEED_DT',
#  'LAND_HSTD_VAL',
#  'LAND_NON_HSTD_VAL',
#  'IMPRV_HSTD_VAL',
#  'IMPRV_NON_HSTD_VAL',
#  'AG_USE_VAL',
#  'AG_MARKET',
#  'APPRAISED_VAL',
#  'TEN_PERCENT',
#  'ASSESSED_VAL',
#  'MARKET_VAL',
#  'IMPRV_STATE_CD',
#  'LAND_STATE_CD',
#  'HS_EXEMPT',
#  'OV65_EXEMPT',
#  'ENTITIES',
#  'LAND_ACRES',
#  'SUM_IMPRV_SQFT',
#  'YR_BUILT',
#  'DEPRECIATION_YR',
#  'IMPRV_TYPE',
#  'IMPRV_TYPE_DESC',
#  'COA_TAXABLE_VAL',
#  'TRAVIS_TAX_VAL',
#  'CONSTRAINED_AREA',
#  'BASEZONE',
#  'EFF_ZONE',
#  'LOTSIZE',
#  'COUNCIL_DI',
#  'I35SIDE',
#  'TOTAL_IMP_',
#  'TOTAL_LAND',
# ...

# %%
df2 = df1.head(100)  #making a smaller subset so it can be included in git repo for experiments away from workstation

# %%
df2
# Out:
#          PID_10  PROP_ID CONDOID  PREVIOUSLU  PREVIOUSGE  LAND_USE  \
# 0   100030105.0   100008     NaN         300         300       300
# 1   100030109.0   100012     NaN         330         330       330
# 2   100030110.0   100013     NaN         300         300       300
# 3   100030111.0   100014     NaN         300         300       300
# 4   100030112.0   100015     NaN         300         300       300
# 5   100030115.0   100018     NaN         300         300       300
# 6   100030116.0   100019     NaN         300         300       300
# 7   100030117.0   365458     NaN         300         300       300
# 8   100030201.0   100020     NaN         520         500       520
# 9   100030203.0   100022     NaN         400         400       400
# 10  100030204.0   100023     NaN         900         900       900
# 11  100030205.0   100024     NaN         300         300       300
# 12  100030206.0   100025     NaN         900         900       900
# ...

# %%
df2.to_pickle('./100entries.pkl')

# %%
df3 = pd.read_pickle("./100entries.pkl")

# %%
df3
# Out:
#          PID_10  PROP_ID CONDOID  PREVIOUSLU  PREVIOUSGE  LAND_USE  \
# 0   100030105.0   100008     NaN         300         300       300
# 1   100030109.0   100012     NaN         330         330       330
# 2   100030110.0   100013     NaN         300         300       300
# 3   100030111.0   100014     NaN         300         300       300
# 4   100030112.0   100015     NaN         300         300       300
# 5   100030115.0   100018     NaN         300         300       300
# 6   100030116.0   100019     NaN         300         300       300
# 7   100030117.0   365458     NaN         300         300       300
# 8   100030201.0   100020     NaN         520         500       520
# 9   100030203.0   100022     NaN         400         400       400
# 10  100030204.0   100023     NaN         900         900       900
# 11  100030205.0   100024     NaN         300         300       300
# 12  100030206.0   100025     NaN         900         900       900
# ...
